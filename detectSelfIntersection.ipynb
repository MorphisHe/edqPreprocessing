# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("all_states_precincts_cname_neighbor_demo_OG_anomalous_fixNeighborVA.json")

# %%
va = gdf[gdf["State"] == "va"]

# %%
county = gpd.read_file("VA/geographic/County/VA_County_Cleaned.json")

# %%
g = county[county["County"] == "Bristol City"]["geometry"].iloc[-1]

# %%
g

# %%
g.intersects(g)
# Out:
# True

# %%
county.head(2)
# Out:
#              County                                           geometry
# 0   Accomack County  POLYGON ((-75.62204 37.45679, -75.62465 37.457...
# 1  Albemarle County  POLYGON ((-78.36880 38.18409, -78.36476 38.183...

# %%
g1 = county[county["County"] == "Carroll County"]["geometry"].iloc[-1]

# %%
g1

# %%
g1.intersects(g1)
# Out:
# True

# %%
g1.crosses(g1)
# Out:
# False

# %%
seem = set()
dup_flag = 0
for pt in g.exterior.coords:
    if dup_flag:
        print("fail")
    else:
        if pt in seem:
            dup_flag = 1
        else:
            seem.add(pt)
print("Good")
# Out:
# Good

# %%
print(len(seem))
# Out:
# 501

# %%
len(g.exterior.coords)
# Out:
# 502
